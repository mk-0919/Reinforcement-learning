# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
              dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                  interval=50)
    anim.save('movie_cartpole_PXR.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99
MAX_STEPS = 200
NUM_EPISODES = 500

# %%
class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0

    def push(self, state, action, state_next, reward):

        if len(self.memory) < self.capacity:
            self.memory.append(None)

        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
TD_ERROR_EPSILON = 0.0001

class TDerrorMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY #メモリの最大長
        self.memory = []#経験を保存する変数
        self.index = 0#保存するindexを示す変数

    def push(self, td_error):
        '''TD誤差をメモリに保存'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)

        self.memory[self.index] = td_error
        self.index = (self.index + 1) % self.capacity

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

    def get_prioritized_indexes(self, batch_size):
        '''TD誤差に応じた確率でindexを取得'''

        #TD誤差の和を計算
        sum_absolute_td_error = np.sum(np.absolute(self.memory))
        sum_absolute_td_error += TD_ERROR_EPSILON * len(self.memory)

        #batch_size分の乱数を生成して、昇順に並べる
        rand_list = np.random.uniform(0, sum_absolute_td_error, batch_size)
        rand_list = np.sort(rand_list)

        #作成した乱数で串刺しにして、インデックスを求める
        indexes = []
        idx = 0
        tmp_sum_absolute_td_error = 0
        for rand_num in rand_list:
            while tmp_sum_absolute_td_error < rand_num:
                tmp_sum_absolute_td_error += (abs(self.memory[idx]) + TD_ERROR_EPSILON)
                idx += 1

            #微小値を計算に使用した関係でindexがメモリの長さを超えた場合の補正
            if idx >= len(self.memory):
                idx = len(self.memory) - 1
            indexes.append(idx)

        return indexes

    def update_td_error(self, updated_td_errors):
        '''TD誤差の更新'''
        self.memory = updated_td_errors

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions #CartPoleの行動
        self.memory = ReplayMemory(CAPACITY)#経験を記憶するメモリオブジェクト

        #ニューラルネットワーク構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)#ネットワークの形を出力

        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)#最適化手法の設定

        self.td_error_memory = TDerrorMemory(CAPACITY)

    def replay(self, episode):
        '''Experience Replayでネットワークの結合パラメータを学習'''
        #1. メモリサイズの確認
        if len(self.memory) < BATCH_SIZE:
            return
        
        #2. ミニバッチ作成
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch(episode)

        #3. 教師信号となるQ(s_t, a_t)値を求める
        self.expected_state_action_values = self.get_expected_state_action_values()

        #4. 結合パラメータの更新
        self.update_main_q_network()

    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()#推論モードに切り替え
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])

        return action

    def make_minibatch(self, episode):
        '''2.ミニバッチの作成'''

        #2.1 メモリからミニバッチ分のデータを取り出す
        if episode < 30:
            transitions = self.memory.sample(BATCH_SIZE)
        else:
            #TD誤差に応じてミニバッチを取り出す
            indexes = self.td_error_memory.get_prioritized_indexes(BATCH_SIZE)
            transitions = [self.memory.memory[n] for n in indexes]

        #2.2 各変数をミニバッチに対応する形に変形
        batch = Transition(*zip(*transitions))

        #2.3 各変数の要素をミニバッチに対応する形に変形する
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3.教師信号となるQ(s_t, a_t)値を求める'''

        #3.1 ネットワークを推論モードに切り替え
        self.main_q_network.eval()
        self.target_q_network.eval()

        #3.2 ネットワークが出力したQ(s_t, a_t)を求める
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)

        #3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))

        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        #3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 結合パラメータの更新'''

        #4.1 ネットワークを訓練モードに切り替える
        self.main_q_network.train()

        #4.2 損失関数を計算する(smooth_l1_lossはHuberloss)
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))

        #4.3 結合パラメータを更新する
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_q_network(self):
        '''Target Q-NetworkをMainと同じにする'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

    def update_td_error_memory(self):
        '''TD誤差メモリに格納されているTD誤差を更新する'''

        #ネットワークを推論モードに
        self.main_q_network.eval()
        self.target_q_network.eval()

        #全メモリでミニバッチを作成
        transitions = self.memory.memory
        batch = Transition(*zip(*transitions))

        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        #ネットワークが出力したQ(s_t, a_t)を求める
        state_action_values = self.main_q_network(state_batch).gather(1, action_batch)

        #cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))

        #まずは全部0にしておく、サイズはメモリの長さ
        next_state_values = torch.zeros(len(self.memory))
        a_m = torch.zeros(len(self.memory)).type(torch.LongTensor)

        #次の状態での最大Q値の行動a_mをMain Q-networkから求める
        a_m[non_final_mask] = self.main_q_network(non_final_next_states).detach().max(1)[1]

        #次の状態があるものだけにフィルターし、size 32を32*1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        #次の状態があるindexの、行動a_mのQ値をtarget Q-networkから求める
        next_state_values[non_final_mask] = self.target_q_network(non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        #TD誤差を求める
        td_errors = (reward_batch + GAMMA * next_state_values) - \
            state_action_values.squeeze()

        #TD誤差メモリを更新、Tensorをdetach()で取り出し、NumPyにしてから、Pythonのリストまで変換
        self.td_error_memory.memory = td_errors.detach().numpy().tolist()

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions) 

    def update_q_function(self, episode):
        '''Q関数を更新する'''
        self.brain.replay(episode)

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-NetworkをMain Q-Networkと同じに更新'''
        self.brain.update_target_q_network()
        
    def memorize_td_error(self, td_error):  
        '''TD誤差メモリにTD誤差を格納'''
        self.brain.td_error_memory.push(td_error)
        
    def update_td_error_memory(self): 
        '''TD誤差メモリに格納されているTD誤差を更新する'''
        self.brain.update_td_error_memory()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n

        self.agent = Agent(num_states, num_actions)

    def run(self):
        episode_10_list = np.zeros(10)

        complete_episodes = 0
        episode_final = False
        frames = []

        for episode in range(NUM_EPISODES):
            observation = self.env.reset()

            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)

            for step in range(MAX_STEPS):
                if episode_final is True:
                    frames.append(self.env.render(mode = 'rgb_array'))
                
                action = self.agent.get_action(state, episode)

                observation_next, _, done, _ = self.env.step(action.item())
                if done:
                    state_next = None

                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)

                self.agent.memorize(state, action, state_next, reward)

                self.agent.memorize_td_error(0)

                self.agent.update_q_function(episode)

                state = state_next

                if done:
                    print('%d Episode: Finished after %d steps : 10試行の平均step数 = %.1lf' %(episode, step + 1, episode_10_list.mean()))

                    self.agent.update_td_error_memory()

                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break

            if episode_final is True:
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 14 steps : 10試行の平均step数 = 1.4
# 1 Episode: Finished after 9 steps : 10試行の平均step数 = 2.3
# 2 Episode: Finished after 11 steps : 10試行の平均step数 = 3.4
# 3 Episode: Finished after 9 steps : 10試行の平均step数 = 4.3
# 4 Episode: Finished after 10 steps : 10試行の平均step数 = 5.3
# 5 Episode: Finished after 9 steps : 10試行の平均step数 = 6.2
# 6 Episode: Finished after 14 steps : 10試行の平均step数 = 7.6
# 7 Episode: Finished after 8 steps : 10試行の平均step数 = 8.4
# 8 Episode: Finished after 9 steps : 10試行の平均step数 = 9.3
# 9 Episode: Finished after 9 steps : 10試行の平均step数 = 10.2
# 10 Episode: Finished after 9 steps : 10試行の平均step数 = 9.7
# 11 Episode: Finished after 9 steps : 10試行の平均step数 = 9.7
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:148: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m[non_final_mask] = self.main_q_network(non_final_next_states).detach().max(1)[1]
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:151: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:154: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   next_state_values[non_final_mask] = self.target_q_network(non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:91: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m[non_final_mask] = self.main_q_network(
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:94: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)
# C:\Users\owner\AppData\Local\Temp/ipykernel_10744/2553595796.py:96: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
# 12 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 13 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 14 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 15 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 16 Episode: Finished after 9 steps : 10試行の平均step数 = 9.1
# 17 Episode: Finished after 11 steps : 10試行の平均step数 = 9.4
# 18 Episode: Finished after 10 steps : 10試行の平均step数 = 9.5
# 19 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 20 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 21 Episode: Finished after 13 steps : 10試行の平均step数 = 10.1
# 22 Episode: Finished after 13 steps : 10試行の平均step数 = 10.5
# 23 Episode: Finished after 10 steps : 10試行の平均step数 = 10.5
# 24 Episode: Finished after 9 steps : 10試行の平均step数 = 10.4
# 25 Episode: Finished after 12 steps : 10試行の平均step数 = 10.7
# 26 Episode: Finished after 9 steps : 10試行の平均step数 = 10.7
# 27 Episode: Finished after 11 steps : 10試行の平均step数 = 10.7
# 28 Episode: Finished after 12 steps : 10試行の平均step数 = 10.9
# 29 Episode: Finished after 9 steps : 10試行の平均step数 = 10.8
# 30 Episode: Finished after 10 steps : 10試行の平均step数 = 10.8
# 31 Episode: Finished after 11 steps : 10試行の平均step数 = 10.6
# 32 Episode: Finished after 10 steps : 10試行の平均step数 = 10.3
# 33 Episode: Finished after 9 steps : 10試行の平均step数 = 10.2
# 34 Episode: Finished after 9 steps : 10試行の平均step数 = 10.2
# 35 Episode: Finished after 9 steps : 10試行の平均step数 = 9.9
# 36 Episode: Finished after 9 steps : 10試行の平均step数 = 9.9
# 37 Episode: Finished after 10 steps : 10試行の平均step数 = 9.8
# 38 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 39 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 40 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 41 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 42 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 43 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 44 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 45 Episode: Finished after 11 steps : 10試行の平均step数 = 9.8
# 46 Episode: Finished after 9 steps : 10試行の平均step数 = 9.8
# 47 Episode: Finished after 8 steps : 10試行の平均step数 = 9.6
# 48 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 49 Episode: Finished after 8 steps : 10試行の平均step数 = 9.4
# 50 Episode: Finished after 9 steps : 10試行の平均step数 = 9.3
# 51 Episode: Finished after 8 steps : 10試行の平均step数 = 9.1
# 52 Episode: Finished after 10 steps : 10試行の平均step数 = 9.2
# 53 Episode: Finished after 9 steps : 10試行の平均step数 = 9.2
# 54 Episode: Finished after 10 steps : 10試行の平均step数 = 9.2
# 55 Episode: Finished after 9 steps : 10試行の平均step数 = 9.0
# 56 Episode: Finished after 10 steps : 10試行の平均step数 = 9.1
# 57 Episode: Finished after 9 steps : 10試行の平均step数 = 9.2
# 58 Episode: Finished after 11 steps : 10試行の平均step数 = 9.3
# 59 Episode: Finished after 10 steps : 10試行の平均step数 = 9.5
# 60 Episode: Finished after 11 steps : 10試行の平均step数 = 9.7
# 61 Episode: Finished after 13 steps : 10試行の平均step数 = 10.2
# 62 Episode: Finished after 14 steps : 10試行の平均step数 = 10.6
# 63 Episode: Finished after 15 steps : 10試行の平均step数 = 11.2
# 64 Episode: Finished after 13 steps : 10試行の平均step数 = 11.5
# 65 Episode: Finished after 11 steps : 10試行の平均step数 = 11.7
# 66 Episode: Finished after 13 steps : 10試行の平均step数 = 12.0
# 67 Episode: Finished after 10 steps : 10試行の平均step数 = 12.1
# 68 Episode: Finished after 14 steps : 10試行の平均step数 = 12.4
# 69 Episode: Finished after 13 steps : 10試行の平均step数 = 12.7
# 70 Episode: Finished after 14 steps : 10試行の平均step数 = 13.0
# 71 Episode: Finished after 16 steps : 10試行の平均step数 = 13.3
# 72 Episode: Finished after 12 steps : 10試行の平均step数 = 13.1
# 73 Episode: Finished after 10 steps : 10試行の平均step数 = 12.6
# 74 Episode: Finished after 13 steps : 10試行の平均step数 = 12.6
# 75 Episode: Finished after 13 steps : 10試行の平均step数 = 12.8
# 76 Episode: Finished after 13 steps : 10試行の平均step数 = 12.8
# 77 Episode: Finished after 13 steps : 10試行の平均step数 = 13.1
# 78 Episode: Finished after 11 steps : 10試行の平均step数 = 12.8
# 79 Episode: Finished after 14 steps : 10試行の平均step数 = 12.9
# 80 Episode: Finished after 14 steps : 10試行の平均step数 = 12.9
# 81 Episode: Finished after 14 steps : 10試行の平均step数 = 12.7
# 82 Episode: Finished after 15 steps : 10試行の平均step数 = 13.0
# 83 Episode: Finished after 10 steps : 10試行の平均step数 = 13.0
# 84 Episode: Finished after 15 steps : 10試行の平均step数 = 13.2
# 85 Episode: Finished after 13 steps : 10試行の平均step数 = 13.2
# 86 Episode: Finished after 14 steps : 10試行の平均step数 = 13.3
# 87 Episode: Finished after 13 steps : 10試行の平均step数 = 13.3
# 88 Episode: Finished after 14 steps : 10試行の平均step数 = 13.6
# 89 Episode: Finished after 12 steps : 10試行の平均step数 = 13.4
# 90 Episode: Finished after 12 steps : 10試行の平均step数 = 13.2
# 91 Episode: Finished after 13 steps : 10試行の平均step数 = 13.1
# 92 Episode: Finished after 16 steps : 10試行の平均step数 = 13.2
# 93 Episode: Finished after 13 steps : 10試行の平均step数 = 13.5
# 94 Episode: Finished after 15 steps : 10試行の平均step数 = 13.5
# 95 Episode: Finished after 13 steps : 10試行の平均step数 = 13.5
# 96 Episode: Finished after 12 steps : 10試行の平均step数 = 13.3
# 97 Episode: Finished after 11 steps : 10試行の平均step数 = 13.1
# 98 Episode: Finished after 14 steps : 10試行の平均step数 = 13.1
# 99 Episode: Finished after 12 steps : 10試行の平均step数 = 13.1
# 100 Episode: Finished after 11 steps : 10試行の平均step数 = 13.0
# 101 Episode: Finished after 14 steps : 10試行の平均step数 = 13.1
# 102 Episode: Finished after 11 steps : 10試行の平均step数 = 12.6
# 103 Episode: Finished after 17 steps : 10試行の平均step数 = 13.0
# 104 Episode: Finished after 12 steps : 10試行の平均step数 = 12.7
# 105 Episode: Finished after 13 steps : 10試行の平均step数 = 12.7
# 106 Episode: Finished after 12 steps : 10試行の平均step数 = 12.7
# 107 Episode: Finished after 11 steps : 10試行の平均step数 = 12.7
# 108 Episode: Finished after 15 steps : 10試行の平均step数 = 12.8
# 109 Episode: Finished after 11 steps : 10試行の平均step数 = 12.7
# 110 Episode: Finished after 12 steps : 10試行の平均step数 = 12.8
# 111 Episode: Finished after 11 steps : 10試行の平均step数 = 12.5
# 112 Episode: Finished after 11 steps : 10試行の平均step数 = 12.5
# 113 Episode: Finished after 14 steps : 10試行の平均step数 = 12.2
# 114 Episode: Finished after 15 steps : 10試行の平均step数 = 12.5
# 115 Episode: Finished after 13 steps : 10試行の平均step数 = 12.5
# 116 Episode: Finished after 11 steps : 10試行の平均step数 = 12.4
# 117 Episode: Finished after 11 steps : 10試行の平均step数 = 12.4
# 118 Episode: Finished after 11 steps : 10試行の平均step数 = 12.0
# 119 Episode: Finished after 16 steps : 10試行の平均step数 = 12.5
# 120 Episode: Finished after 14 steps : 10試行の平均step数 = 12.7
# 121 Episode: Finished after 13 steps : 10試行の平均step数 = 12.9
# 122 Episode: Finished after 14 steps : 10試行の平均step数 = 13.2
# 123 Episode: Finished after 13 steps : 10試行の平均step数 = 13.1
# 124 Episode: Finished after 16 steps : 10試行の平均step数 = 13.2
# 125 Episode: Finished after 12 steps : 10試行の平均step数 = 13.1
# 126 Episode: Finished after 14 steps : 10試行の平均step数 = 13.4
# 127 Episode: Finished after 21 steps : 10試行の平均step数 = 14.4
# 128 Episode: Finished after 12 steps : 10試行の平均step数 = 14.5
# 129 Episode: Finished after 14 steps : 10試行の平均step数 = 14.3
# 130 Episode: Finished after 13 steps : 10試行の平均step数 = 14.2
# 131 Episode: Finished after 16 steps : 10試行の平均step数 = 14.5
# 132 Episode: Finished after 14 steps : 10試行の平均step数 = 14.5
# 133 Episode: Finished after 24 steps : 10試行の平均step数 = 15.6
# 134 Episode: Finished after 22 steps : 10試行の平均step数 = 16.2
# 135 Episode: Finished after 19 steps : 10試行の平均step数 = 16.9
# 136 Episode: Finished after 20 steps : 10試行の平均step数 = 17.5
# 137 Episode: Finished after 17 steps : 10試行の平均step数 = 17.1
# 138 Episode: Finished after 21 steps : 10試行の平均step数 = 18.0
# 139 Episode: Finished after 22 steps : 10試行の平均step数 = 18.8
# 140 Episode: Finished after 28 steps : 10試行の平均step数 = 20.3
# 141 Episode: Finished after 37 steps : 10試行の平均step数 = 22.4
# 142 Episode: Finished after 28 steps : 10試行の平均step数 = 23.8
# 143 Episode: Finished after 30 steps : 10試行の平均step数 = 24.4
# 144 Episode: Finished after 34 steps : 10試行の平均step数 = 25.6
# 145 Episode: Finished after 34 steps : 10試行の平均step数 = 27.1
# 146 Episode: Finished after 38 steps : 10試行の平均step数 = 28.9
# 147 Episode: Finished after 30 steps : 10試行の平均step数 = 30.2
# 148 Episode: Finished after 36 steps : 10試行の平均step数 = 31.7
# 149 Episode: Finished after 42 steps : 10試行の平均step数 = 33.7
# 150 Episode: Finished after 76 steps : 10試行の平均step数 = 38.5
# 151 Episode: Finished after 40 steps : 10試行の平均step数 = 38.8
# 152 Episode: Finished after 68 steps : 10試行の平均step数 = 42.8
# 153 Episode: Finished after 84 steps : 10試行の平均step数 = 48.2
# 154 Episode: Finished after 53 steps : 10試行の平均step数 = 50.1
# 155 Episode: Finished after 58 steps : 10試行の平均step数 = 52.5
# 156 Episode: Finished after 63 steps : 10試行の平均step数 = 55.0
# 157 Episode: Finished after 52 steps : 10試行の平均step数 = 57.2
# 158 Episode: Finished after 36 steps : 10試行の平均step数 = 57.2
# 159 Episode: Finished after 97 steps : 10試行の平均step数 = 62.7
# 160 Episode: Finished after 84 steps : 10試行の平均step数 = 63.5
# 161 Episode: Finished after 44 steps : 10試行の平均step数 = 63.9
# 162 Episode: Finished after 36 steps : 10試行の平均step数 = 60.7
# 163 Episode: Finished after 66 steps : 10試行の平均step数 = 58.9
# 164 Episode: Finished after 53 steps : 10試行の平均step数 = 58.9
# 165 Episode: Finished after 37 steps : 10試行の平均step数 = 56.8
# 166 Episode: Finished after 66 steps : 10試行の平均step数 = 57.1
# 167 Episode: Finished after 78 steps : 10試行の平均step数 = 59.7
# 168 Episode: Finished after 81 steps : 10試行の平均step数 = 64.2
# 169 Episode: Finished after 47 steps : 10試行の平均step数 = 59.2
# 170 Episode: Finished after 39 steps : 10試行の平均step数 = 54.7
# 171 Episode: Finished after 45 steps : 10試行の平均step数 = 54.8
# 172 Episode: Finished after 58 steps : 10試行の平均step数 = 57.0
# 173 Episode: Finished after 73 steps : 10試行の平均step数 = 57.7
# 174 Episode: Finished after 52 steps : 10試行の平均step数 = 57.6
# 175 Episode: Finished after 57 steps : 10試行の平均step数 = 59.6
# 176 Episode: Finished after 48 steps : 10試行の平均step数 = 57.8
# 177 Episode: Finished after 41 steps : 10試行の平均step数 = 54.1
# 178 Episode: Finished after 50 steps : 10試行の平均step数 = 51.0
# 179 Episode: Finished after 48 steps : 10試行の平均step数 = 51.1
# 180 Episode: Finished after 158 steps : 10試行の平均step数 = 63.0
# 181 Episode: Finished after 51 steps : 10試行の平均step数 = 63.6
# 182 Episode: Finished after 43 steps : 10試行の平均step数 = 62.1
# 183 Episode: Finished after 51 steps : 10試行の平均step数 = 59.9
# 184 Episode: Finished after 53 steps : 10試行の平均step数 = 60.0
# 185 Episode: Finished after 47 steps : 10試行の平均step数 = 59.0
# 186 Episode: Finished after 77 steps : 10試行の平均step数 = 61.9
# 187 Episode: Finished after 44 steps : 10試行の平均step数 = 62.2
# 188 Episode: Finished after 127 steps : 10試行の平均step数 = 69.9
# 189 Episode: Finished after 49 steps : 10試行の平均step数 = 70.0
# 190 Episode: Finished after 53 steps : 10試行の平均step数 = 59.5
# 191 Episode: Finished after 57 steps : 10試行の平均step数 = 60.1
# 192 Episode: Finished after 108 steps : 10試行の平均step数 = 66.6
# 193 Episode: Finished after 112 steps : 10試行の平均step数 = 72.7
# 194 Episode: Finished after 77 steps : 10試行の平均step数 = 75.1
# 195 Episode: Finished after 52 steps : 10試行の平均step数 = 75.6
# Exception ignored in: <function Viewer.__del__ at 0x000001F9A1431310>
# Traceback (most recent call last):
#   File "C:\Users\owner\anaconda3\envs\rl_env\lib\site-packages\gym\envs\classic_control\rendering.py", line 152, in __del__
#     self.close()
#   File "C:\Users\owner\anaconda3\envs\rl_env\lib\site-packages\gym\envs\classic_control\rendering.py", line 71, in close
#     self.window.close()
#   File "C:\Users\owner\anaconda3\envs\rl_env\lib\site-packages\pyglet\window\win32\__init__.py", line 299, in close
#     super(Win32Window, self).close()
#   File "C:\Users\owner\anaconda3\envs\rl_env\lib\site-packages\pyglet\window\__init__.py", line 823, in close
#     app.windows.remove(self)
#   File "C:\Users\owner\anaconda3\envs\rl_env\lib\_weakrefset.py", line 109, in remove
#     self.data.remove(ref(item))
# KeyError: <weakref at 0x000001F99AD7D040; to 'Win32Window' at 0x000001F99C022A00>
# 196 Episode: Finished after 60 steps : 10試行の平均step数 = 73.9
# 197 Episode: Finished after 98 steps : 10試行の平均step数 = 79.3
# 198 Episode: Finished after 56 steps : 10試行の平均step数 = 72.2
# 199 Episode: Finished after 45 steps : 10試行の平均step数 = 71.8
# 200 Episode: Finished after 103 steps : 10試行の平均step数 = 76.8
# 201 Episode: Finished after 53 steps : 10試行の平均step数 = 76.4
# 202 Episode: Finished after 46 steps : 10試行の平均step数 = 70.2
# 203 Episode: Finished after 65 steps : 10試行の平均step数 = 65.5
# 204 Episode: Finished after 40 steps : 10試行の平均step数 = 61.8
# 205 Episode: Finished after 200 steps : 10試行の平均step数 = 76.6
# 206 Episode: Finished after 55 steps : 10試行の平均step数 = 76.1
# 207 Episode: Finished after 60 steps : 10試行の平均step数 = 72.3
# 208 Episode: Finished after 163 steps : 10試行の平均step数 = 83.0
# 209 Episode: Finished after 181 steps : 10試行の平均step数 = 96.6
# 210 Episode: Finished after 58 steps : 10試行の平均step数 = 92.1
# 211 Episode: Finished after 75 steps : 10試行の平均step数 = 94.3
# 212 Episode: Finished after 60 steps : 10試行の平均step数 = 95.7
# 213 Episode: Finished after 79 steps : 10試行の平均step数 = 97.1
# 214 Episode: Finished after 200 steps : 10試行の平均step数 = 113.1
# 215 Episode: Finished after 67 steps : 10試行の平均step数 = 99.8
# 216 Episode: Finished after 61 steps : 10試行の平均step数 = 100.4
# 217 Episode: Finished after 65 steps : 10試行の平均step数 = 100.9
# 218 Episode: Finished after 64 steps : 10試行の平均step数 = 91.0
# 219 Episode: Finished after 85 steps : 10試行の平均step数 = 81.4
# 220 Episode: Finished after 49 steps : 10試行の平均step数 = 80.5
# 221 Episode: Finished after 59 steps : 10試行の平均step数 = 78.9
# 222 Episode: Finished after 89 steps : 10試行の平均step数 = 81.8
# 223 Episode: Finished after 67 steps : 10試行の平均step数 = 80.6
# 224 Episode: Finished after 200 steps : 10試行の平均step数 = 80.6
# 225 Episode: Finished after 52 steps : 10試行の平均step数 = 79.1
# 226 Episode: Finished after 118 steps : 10試行の平均step数 = 84.8
# 227 Episode: Finished after 70 steps : 10試行の平均step数 = 85.3
# 228 Episode: Finished after 104 steps : 10試行の平均step数 = 89.3
# 229 Episode: Finished after 59 steps : 10試行の平均step数 = 86.7
# 230 Episode: Finished after 78 steps : 10試行の平均step数 = 89.6
# 231 Episode: Finished after 120 steps : 10試行の平均step数 = 95.7
# 232 Episode: Finished after 200 steps : 10試行の平均step数 = 106.8
# 233 Episode: Finished after 162 steps : 10試行の平均step数 = 116.3
# 234 Episode: Finished after 100 steps : 10試行の平均step数 = 106.3
# 235 Episode: Finished after 77 steps : 10試行の平均step数 = 108.8
# 236 Episode: Finished after 200 steps : 10試行の平均step数 = 117.0
# 237 Episode: Finished after 89 steps : 10試行の平均step数 = 118.9
# 238 Episode: Finished after 90 steps : 10試行の平均step数 = 117.5
# 239 Episode: Finished after 88 steps : 10試行の平均step数 = 120.4
# 240 Episode: Finished after 200 steps : 10試行の平均step数 = 132.6
# 241 Episode: Finished after 149 steps : 10試行の平均step数 = 135.5
# 242 Episode: Finished after 177 steps : 10試行の平均step数 = 133.2
# 243 Episode: Finished after 146 steps : 10試行の平均step数 = 131.6
# 244 Episode: Finished after 102 steps : 10試行の平均step数 = 131.8
# 245 Episode: Finished after 97 steps : 10試行の平均step数 = 133.8
# 246 Episode: Finished after 76 steps : 10試行の平均step数 = 121.4
# 247 Episode: Finished after 100 steps : 10試行の平均step数 = 122.5
# 248 Episode: Finished after 74 steps : 10試行の平均step数 = 120.9
# 249 Episode: Finished after 120 steps : 10試行の平均step数 = 124.1
# 250 Episode: Finished after 79 steps : 10試行の平均step数 = 112.0
# 251 Episode: Finished after 108 steps : 10試行の平均step数 = 107.9
# 252 Episode: Finished after 87 steps : 10試行の平均step数 = 98.9
# 253 Episode: Finished after 111 steps : 10試行の平均step数 = 95.4
# 254 Episode: Finished after 119 steps : 10試行の平均step数 = 97.1
# 255 Episode: Finished after 81 steps : 10試行の平均step数 = 95.5
# 256 Episode: Finished after 74 steps : 10試行の平均step数 = 95.3
# 257 Episode: Finished after 143 steps : 10試行の平均step数 = 99.6
# 258 Episode: Finished after 81 steps : 10試行の平均step数 = 100.3
# 259 Episode: Finished after 123 steps : 10試行の平均step数 = 100.6
# 260 Episode: Finished after 108 steps : 10試行の平均step数 = 103.5
# 261 Episode: Finished after 98 steps : 10試行の平均step数 = 102.5
# 262 Episode: Finished after 135 steps : 10試行の平均step数 = 107.3
# 263 Episode: Finished after 200 steps : 10試行の平均step数 = 116.2
# 264 Episode: Finished after 71 steps : 10試行の平均step数 = 111.4
# 265 Episode: Finished after 200 steps : 10試行の平均step数 = 123.3
# 266 Episode: Finished after 77 steps : 10試行の平均step数 = 123.6
# 267 Episode: Finished after 91 steps : 10試行の平均step数 = 118.4
# 268 Episode: Finished after 200 steps : 10試行の平均step数 = 130.3
# 269 Episode: Finished after 200 steps : 10試行の平均step数 = 138.0
# 270 Episode: Finished after 200 steps : 10試行の平均step数 = 147.2
# 271 Episode: Finished after 154 steps : 10試行の平均step数 = 152.8
# 272 Episode: Finished after 200 steps : 10試行の平均step数 = 159.3
# 273 Episode: Finished after 200 steps : 10試行の平均step数 = 159.3
# 274 Episode: Finished after 200 steps : 10試行の平均step数 = 172.2
# 275 Episode: Finished after 200 steps : 10試行の平均step数 = 172.2
# 276 Episode: Finished after 200 steps : 10試行の平均step数 = 184.5
# 277 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 278 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 279 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 280 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 281 Episode: Finished after 200 steps : 10試行の平均step数 = 200.0
# 10回連続成功
# 282 Episode: Finished after 200 steps : 10試行の平均step数 = 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgZOTYFTVEBGMOOLJD">
#     <br>
#     <input id="_anim_sliderZOTYFTVEBGMOOLJD" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animZOTYFTVEBGMOOLJD.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animZOTYFTVEBGMOOLJD.slower()">&#8211;</button>
#     <button onclick="animZOTYFTVEBGMOOLJD.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animZOTYFTVEBGMOOLJD.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectZOTYFTVEBGMOOLJD" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgZOTYFTVEBGMOOLJD";
#     var slider_id = "_anim_sliderZOTYFTVEBGMOOLJD";
#     var loop_select_id = "_anim_loop_selectZOTYFTVEBGMOOLJD";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
