# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
              dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                  interval=50)
    anim.save('movie_cartpole_DDQN.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.99
MAX_STEPS = 200
NUM_EPISODES = 500

# %%
class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY
        self.memory = []
        self.index = 0

    def push(self, state, action, state_next, reward):

        if len(self.memory) < self.capacity:
            self.memory.append(None)

        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        self.fc3 = nn.Linear(n_mid, n_out)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        output = self.fc3(h2)
        return output

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions #CartPoleの行動
        self.memory = ReplayMemory(CAPACITY)#経験を記憶するメモリオブジェクト

        #ニューラルネットワーク構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)#ネットワークの形を出力

        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)#最適化手法の設定

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''
        #1. メモリサイズの確認
        if len(self.memory) < BATCH_SIZE:
            return
        
        #2. ミニバッチ作成
        self.batch, self.state_batch, self.action_batch, self.reward_batch,self.non_final_next_states = self.make_minibatch()

        #3. 教師信号となるQ(s_t, a_t)値を求める
        self.expected_state_action_values = self.get_expected_state_action_values()

        #4. 結合パラメータの更新
        self.update_main_q_network()

    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()#推論モードに切り替え
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])

        return action

    def make_minibatch(self):
        '''2.ミニバッチの作成'''

        #2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        #2.2 各変数をミニバッチに対応する形に変形
        batch = Transition(*zip(*transitions))

        #2.3 各変数の要素をミニバッチに対応する形に変形する
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3.教師信号となるQ(s_t, a_t)値を求める'''

        #3.1 ネットワークを推論モードに切り替え
        self.main_q_network.eval()
        self.target_q_network.eval()

        #3.2 ネットワークが出力したQ(s_t, a_t)を求める
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)

        #3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))

        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        #3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 結合パラメータの更新'''

        #4.1 ネットワークを訓練モードに切り替える
        self.main_q_network.train()

        #4.2 損失関数を計算する(smooth_l1_lossはHuberloss)
        loss = F.smooth_l1_loss(self.state_action_values,self.expected_state_action_values.unsqueeze(1))

        #4.3 結合パラメータを更新する
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

    def update_target_q_network(self):
        '''Target Q-NetworkをMainと同じにする'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
    
    def update_q_function(self):
        self.brain.replay()

    def get_acton(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        self.brain.update_target_q_network()

# %%
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        self.num_states = self.env.observation_space.shape[0]
        self.num_actions = self.env.action_space.n

        self.agent = Agent(self.num_states, self.num_actions)

    def run(self):
        episode_10_list = np.zeros(10)

        complete_episodes = 0
        episode_final = False
        frames = []

        for episode in range(NUM_EPISODES):
            observation = self.env.reset()

            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)

            for step in range(MAX_STEPS):
                if episode_final is True:
                    frames.append(self.env.render(mode = 'rgb_array'))
                
                action = self.agent.get_acton(state, episode)

                observation_next, _, done, _ = self.env.step(action.item())
                if done:
                    state_next = None

                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)

                self.agent.memorize(state, action, state_next, reward)

                self.agent.update_q_function()

                state = state_next

                if done:
                    print('%d Episode: Finished after %d steps : 10試行の平均step数 = %.1f' %(episode, step + 1, episode_10_list.mean()))

                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break

            if episode_final is True:
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 15 steps : 10試行の平均step数 = 1.5
# 1 Episode: Finished after 12 steps : 10試行の平均step数 = 2.7
# 2 Episode: Finished after 12 steps : 10試行の平均step数 = 3.9
# 3 Episode: Finished after 10 steps : 10試行の平均step数 = 4.9
# 4 Episode: Finished after 9 steps : 10試行の平均step数 = 5.8
# 5 Episode: Finished after 11 steps : 10試行の平均step数 = 6.9
# 6 Episode: Finished after 10 steps : 10試行の平均step数 = 7.9
# 7 Episode: Finished after 10 steps : 10試行の平均step数 = 8.9
# 8 Episode: Finished after 9 steps : 10試行の平均step数 = 9.8
# 9 Episode: Finished after 11 steps : 10試行の平均step数 = 10.9
# 10 Episode: Finished after 11 steps : 10試行の平均step数 = 10.5
# C:\Users\owner\AppData\Local\Temp/ipykernel_15504/831837827.py:84: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m[non_final_mask] = self.main_q_network(
# C:\Users\owner\AppData\Local\Temp/ipykernel_15504/831837827.py:87: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)
# C:\Users\owner\AppData\Local\Temp/ipykernel_15504/831837827.py:89: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:30.)
#   next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
# 11 Episode: Finished after 12 steps : 10試行の平均step数 = 10.5
# 12 Episode: Finished after 11 steps : 10試行の平均step数 = 10.4
# 13 Episode: Finished after 11 steps : 10試行の平均step数 = 10.5
# 14 Episode: Finished after 11 steps : 10試行の平均step数 = 10.7
# 15 Episode: Finished after 12 steps : 10試行の平均step数 = 10.8
# 16 Episode: Finished after 11 steps : 10試行の平均step数 = 10.9
# 17 Episode: Finished after 11 steps : 10試行の平均step数 = 11.0
# 18 Episode: Finished after 12 steps : 10試行の平均step数 = 11.3
# 19 Episode: Finished after 11 steps : 10試行の平均step数 = 11.3
# 20 Episode: Finished after 12 steps : 10試行の平均step数 = 11.4
# 21 Episode: Finished after 10 steps : 10試行の平均step数 = 11.2
# 22 Episode: Finished after 10 steps : 10試行の平均step数 = 11.1
# 23 Episode: Finished after 11 steps : 10試行の平均step数 = 11.1
# 24 Episode: Finished after 12 steps : 10試行の平均step数 = 11.2
# 25 Episode: Finished after 11 steps : 10試行の平均step数 = 11.1
# 26 Episode: Finished after 11 steps : 10試行の平均step数 = 11.1
# 27 Episode: Finished after 9 steps : 10試行の平均step数 = 10.9
# 28 Episode: Finished after 9 steps : 10試行の平均step数 = 10.6
# 29 Episode: Finished after 10 steps : 10試行の平均step数 = 10.5
# 30 Episode: Finished after 9 steps : 10試行の平均step数 = 10.2
# 31 Episode: Finished after 10 steps : 10試行の平均step数 = 10.2
# 32 Episode: Finished after 10 steps : 10試行の平均step数 = 10.2
# 33 Episode: Finished after 10 steps : 10試行の平均step数 = 10.1
# 34 Episode: Finished after 9 steps : 10試行の平均step数 = 9.8
# 35 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 36 Episode: Finished after 10 steps : 10試行の平均step数 = 9.5
# 37 Episode: Finished after 11 steps : 10試行の平均step数 = 9.7
# 38 Episode: Finished after 11 steps : 10試行の平均step数 = 9.9
# 39 Episode: Finished after 10 steps : 10試行の平均step数 = 9.9
# 40 Episode: Finished after 26 steps : 10試行の平均step数 = 11.6
# 41 Episode: Finished after 25 steps : 10試行の平均step数 = 13.1
# 42 Episode: Finished after 23 steps : 10試行の平均step数 = 14.4
# 43 Episode: Finished after 44 steps : 10試行の平均step数 = 17.8
# 44 Episode: Finished after 27 steps : 10試行の平均step数 = 19.6
# 45 Episode: Finished after 11 steps : 10試行の平均step数 = 19.8
# 46 Episode: Finished after 9 steps : 10試行の平均step数 = 19.7
# 47 Episode: Finished after 9 steps : 10試行の平均step数 = 19.5
# 48 Episode: Finished after 9 steps : 10試行の平均step数 = 19.3
# 49 Episode: Finished after 10 steps : 10試行の平均step数 = 19.3
# 50 Episode: Finished after 10 steps : 10試行の平均step数 = 17.7
# 51 Episode: Finished after 8 steps : 10試行の平均step数 = 16.0
# 52 Episode: Finished after 9 steps : 10試行の平均step数 = 14.6
# 53 Episode: Finished after 10 steps : 10試行の平均step数 = 11.2
# 54 Episode: Finished after 9 steps : 10試行の平均step数 = 9.4
# 55 Episode: Finished after 8 steps : 10試行の平均step数 = 9.1
# 56 Episode: Finished after 10 steps : 10試行の平均step数 = 9.2
# 57 Episode: Finished after 9 steps : 10試行の平均step数 = 9.2
# 58 Episode: Finished after 9 steps : 10試行の平均step数 = 9.2
# 59 Episode: Finished after 10 steps : 10試行の平均step数 = 9.2
# 60 Episode: Finished after 10 steps : 10試行の平均step数 = 9.2
# 61 Episode: Finished after 10 steps : 10試行の平均step数 = 9.4
# 62 Episode: Finished after 10 steps : 10試行の平均step数 = 9.5
# 63 Episode: Finished after 10 steps : 10試行の平均step数 = 9.5
# 64 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 65 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 66 Episode: Finished after 8 steps : 10試行の平均step数 = 9.4
# 67 Episode: Finished after 11 steps : 10試行の平均step数 = 9.6
# 68 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 69 Episode: Finished after 11 steps : 10試行の平均step数 = 9.7
# 70 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 71 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 72 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 73 Episode: Finished after 11 steps : 10試行の平均step数 = 9.7
# 74 Episode: Finished after 9 steps : 10試行の平均step数 = 9.7
# 75 Episode: Finished after 9 steps : 10試行の平均step数 = 9.7
# 76 Episode: Finished after 9 steps : 10試行の平均step数 = 9.8
# 77 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 78 Episode: Finished after 9 steps : 10試行の平均step数 = 9.7
# 79 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 80 Episode: Finished after 9 steps : 10試行の平均step数 = 9.5
# 81 Episode: Finished after 12 steps : 10試行の平均step数 = 9.7
# 82 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 83 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 84 Episode: Finished after 8 steps : 10試行の平均step数 = 9.5
# 85 Episode: Finished after 10 steps : 10試行の平均step数 = 9.6
# 86 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 87 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 88 Episode: Finished after 10 steps : 10試行の平均step数 = 9.8
# 89 Episode: Finished after 10 steps : 10試行の平均step数 = 9.9
# 90 Episode: Finished after 9 steps : 10試行の平均step数 = 9.9
# 91 Episode: Finished after 10 steps : 10試行の平均step数 = 9.7
# 92 Episode: Finished after 9 steps : 10試行の平均step数 = 9.6
# 93 Episode: Finished after 12 steps : 10試行の平均step数 = 9.8
# 94 Episode: Finished after 9 steps : 10試行の平均step数 = 9.9
# 95 Episode: Finished after 68 steps : 10試行の平均step数 = 15.7
# 96 Episode: Finished after 44 steps : 10試行の平均step数 = 19.1
# 97 Episode: Finished after 40 steps : 10試行の平均step数 = 22.1
# 98 Episode: Finished after 37 steps : 10試行の平均step数 = 24.8
# 99 Episode: Finished after 39 steps : 10試行の平均step数 = 27.7
# 100 Episode: Finished after 39 steps : 10試行の平均step数 = 30.7
# 101 Episode: Finished after 29 steps : 10試行の平均step数 = 32.6
# 102 Episode: Finished after 42 steps : 10試行の平均step数 = 35.9
# 103 Episode: Finished after 24 steps : 10試行の平均step数 = 37.1
# 104 Episode: Finished after 29 steps : 10試行の平均step数 = 39.1
# 105 Episode: Finished after 33 steps : 10試行の平均step数 = 35.6
# 106 Episode: Finished after 43 steps : 10試行の平均step数 = 35.5
# 107 Episode: Finished after 26 steps : 10試行の平均step数 = 34.1
# 108 Episode: Finished after 36 steps : 10試行の平均step数 = 34.0
# 109 Episode: Finished after 31 steps : 10試行の平均step数 = 33.2
# 110 Episode: Finished after 20 steps : 10試行の平均step数 = 31.3
# 111 Episode: Finished after 25 steps : 10試行の平均step数 = 30.9
# 112 Episode: Finished after 22 steps : 10試行の平均step数 = 28.9
# 113 Episode: Finished after 30 steps : 10試行の平均step数 = 29.5
# 114 Episode: Finished after 36 steps : 10試行の平均step数 = 30.2
# 115 Episode: Finished after 29 steps : 10試行の平均step数 = 29.8
# 116 Episode: Finished after 26 steps : 10試行の平均step数 = 28.1
# 117 Episode: Finished after 25 steps : 10試行の平均step数 = 28.0
# 118 Episode: Finished after 29 steps : 10試行の平均step数 = 27.3
# 119 Episode: Finished after 34 steps : 10試行の平均step数 = 27.6
# 120 Episode: Finished after 37 steps : 10試行の平均step数 = 29.3
# 121 Episode: Finished after 33 steps : 10試行の平均step数 = 30.1
# 122 Episode: Finished after 25 steps : 10試行の平均step数 = 30.4
# 123 Episode: Finished after 23 steps : 10試行の平均step数 = 29.7
# 124 Episode: Finished after 31 steps : 10試行の平均step数 = 29.2
# 125 Episode: Finished after 26 steps : 10試行の平均step数 = 28.9
# 126 Episode: Finished after 33 steps : 10試行の平均step数 = 29.6
# 127 Episode: Finished after 24 steps : 10試行の平均step数 = 29.5
# 128 Episode: Finished after 39 steps : 10試行の平均step数 = 30.5
# 129 Episode: Finished after 33 steps : 10試行の平均step数 = 30.4
# 130 Episode: Finished after 32 steps : 10試行の平均step数 = 29.9
# 131 Episode: Finished after 25 steps : 10試行の平均step数 = 29.1
# 132 Episode: Finished after 22 steps : 10試行の平均step数 = 28.8
# 133 Episode: Finished after 36 steps : 10試行の平均step数 = 30.1
# 134 Episode: Finished after 28 steps : 10試行の平均step数 = 29.8
# 135 Episode: Finished after 45 steps : 10試行の平均step数 = 31.7
# 136 Episode: Finished after 43 steps : 10試行の平均step数 = 32.7
# 137 Episode: Finished after 25 steps : 10試行の平均step数 = 32.8
# 138 Episode: Finished after 20 steps : 10試行の平均step数 = 30.9
# 139 Episode: Finished after 41 steps : 10試行の平均step数 = 31.7
# 140 Episode: Finished after 26 steps : 10試行の平均step数 = 31.1
# 141 Episode: Finished after 29 steps : 10試行の平均step数 = 31.5
# 142 Episode: Finished after 32 steps : 10試行の平均step数 = 32.5
# 143 Episode: Finished after 51 steps : 10試行の平均step数 = 34.0
# 144 Episode: Finished after 35 steps : 10試行の平均step数 = 34.7
# 145 Episode: Finished after 35 steps : 10試行の平均step数 = 33.7
# 146 Episode: Finished after 25 steps : 10試行の平均step数 = 31.9
# 147 Episode: Finished after 27 steps : 10試行の平均step数 = 32.1
# 148 Episode: Finished after 94 steps : 10試行の平均step数 = 39.5
# 149 Episode: Finished after 31 steps : 10試行の平均step数 = 38.5
# 150 Episode: Finished after 43 steps : 10試行の平均step数 = 40.2
# 151 Episode: Finished after 28 steps : 10試行の平均step数 = 40.1
# 152 Episode: Finished after 24 steps : 10試行の平均step数 = 39.3
# 153 Episode: Finished after 28 steps : 10試行の平均step数 = 37.0
# 154 Episode: Finished after 32 steps : 10試行の平均step数 = 36.7
# 155 Episode: Finished after 44 steps : 10試行の平均step数 = 37.6
# 156 Episode: Finished after 27 steps : 10試行の平均step数 = 37.8
# 157 Episode: Finished after 33 steps : 10試行の平均step数 = 38.4
# 158 Episode: Finished after 146 steps : 10試行の平均step数 = 43.6
# 159 Episode: Finished after 31 steps : 10試行の平均step数 = 43.6
# 160 Episode: Finished after 48 steps : 10試行の平均step数 = 44.1
# 161 Episode: Finished after 36 steps : 10試行の平均step数 = 44.9
# 162 Episode: Finished after 30 steps : 10試行の平均step数 = 45.5
# 163 Episode: Finished after 38 steps : 10試行の平均step数 = 46.5
# 164 Episode: Finished after 67 steps : 10試行の平均step数 = 50.0
# 165 Episode: Finished after 30 steps : 10試行の平均step数 = 48.6
# 166 Episode: Finished after 33 steps : 10試行の平均step数 = 49.2
# 167 Episode: Finished after 35 steps : 10試行の平均step数 = 49.4
# 168 Episode: Finished after 31 steps : 10試行の平均step数 = 37.9
# 169 Episode: Finished after 72 steps : 10試行の平均step数 = 42.0
# 170 Episode: Finished after 82 steps : 10試行の平均step数 = 45.4
# 171 Episode: Finished after 40 steps : 10試行の平均step数 = 45.8
# 172 Episode: Finished after 35 steps : 10試行の平均step数 = 46.3
# 173 Episode: Finished after 48 steps : 10試行の平均step数 = 47.3
# 174 Episode: Finished after 59 steps : 10試行の平均step数 = 46.5
# 175 Episode: Finished after 65 steps : 10試行の平均step数 = 50.0
# 176 Episode: Finished after 48 steps : 10試行の平均step数 = 51.5
# 177 Episode: Finished after 43 steps : 10試行の平均step数 = 52.3
# 178 Episode: Finished after 66 steps : 10試行の平均step数 = 55.8
# 179 Episode: Finished after 49 steps : 10試行の平均step数 = 53.5
# 180 Episode: Finished after 58 steps : 10試行の平均step数 = 51.1
# 181 Episode: Finished after 53 steps : 10試行の平均step数 = 52.4
# 182 Episode: Finished after 62 steps : 10試行の平均step数 = 55.1
# 183 Episode: Finished after 54 steps : 10試行の平均step数 = 55.7
# 184 Episode: Finished after 69 steps : 10試行の平均step数 = 56.7
# 185 Episode: Finished after 94 steps : 10試行の平均step数 = 59.6
# 186 Episode: Finished after 60 steps : 10試行の平均step数 = 60.8
# 187 Episode: Finished after 73 steps : 10試行の平均step数 = 63.8
# 188 Episode: Finished after 67 steps : 10試行の平均step数 = 63.9
# 189 Episode: Finished after 78 steps : 10試行の平均step数 = 66.8
# 190 Episode: Finished after 48 steps : 10試行の平均step数 = 65.8
# 191 Episode: Finished after 70 steps : 10試行の平均step数 = 67.5
# 192 Episode: Finished after 82 steps : 10試行の平均step数 = 69.5
# 193 Episode: Finished after 52 steps : 10試行の平均step数 = 69.3
# 194 Episode: Finished after 102 steps : 10試行の平均step数 = 72.6
# 195 Episode: Finished after 65 steps : 10試行の平均step数 = 69.7
# 196 Episode: Finished after 48 steps : 10試行の平均step数 = 68.5
# 197 Episode: Finished after 93 steps : 10試行の平均step数 = 70.5
# 198 Episode: Finished after 91 steps : 10試行の平均step数 = 72.9
# 199 Episode: Finished after 63 steps : 10試行の平均step数 = 71.4
# 200 Episode: Finished after 38 steps : 10試行の平均step数 = 70.4
# 201 Episode: Finished after 48 steps : 10試行の平均step数 = 68.2
# 202 Episode: Finished after 80 steps : 10試行の平均step数 = 68.0
# 203 Episode: Finished after 55 steps : 10試行の平均step数 = 68.3
# 204 Episode: Finished after 52 steps : 10試行の平均step数 = 63.3
# 205 Episode: Finished after 64 steps : 10試行の平均step数 = 63.2
# 206 Episode: Finished after 63 steps : 10試行の平均step数 = 64.7
# 207 Episode: Finished after 117 steps : 10試行の平均step数 = 67.1
# 208 Episode: Finished after 87 steps : 10試行の平均step数 = 66.7
# 209 Episode: Finished after 104 steps : 10試行の平均step数 = 70.8
# 210 Episode: Finished after 99 steps : 10試行の平均step数 = 76.9
# 211 Episode: Finished after 88 steps : 10試行の平均step数 = 80.9
# 212 Episode: Finished after 104 steps : 10試行の平均step数 = 83.3
# 213 Episode: Finished after 90 steps : 10試行の平均step数 = 86.8
# 214 Episode: Finished after 60 steps : 10試行の平均step数 = 87.6
# 215 Episode: Finished after 109 steps : 10試行の平均step数 = 92.1
# 216 Episode: Finished after 82 steps : 10試行の平均step数 = 94.0
# 217 Episode: Finished after 107 steps : 10試行の平均step数 = 93.0
# 218 Episode: Finished after 77 steps : 10試行の平均step数 = 92.0
# 219 Episode: Finished after 102 steps : 10試行の平均step数 = 91.8
# 220 Episode: Finished after 129 steps : 10試行の平均step数 = 94.8
# 221 Episode: Finished after 54 steps : 10試行の平均step数 = 91.4
# 222 Episode: Finished after 71 steps : 10試行の平均step数 = 88.1
# 223 Episode: Finished after 70 steps : 10試行の平均step数 = 86.1
# 224 Episode: Finished after 97 steps : 10試行の平均step数 = 89.8
# 225 Episode: Finished after 60 steps : 10試行の平均step数 = 84.9
# 226 Episode: Finished after 75 steps : 10試行の平均step数 = 84.2
# 227 Episode: Finished after 66 steps : 10試行の平均step数 = 80.1
# 228 Episode: Finished after 88 steps : 10試行の平均step数 = 81.2
# 229 Episode: Finished after 86 steps : 10試行の平均step数 = 79.6
# 230 Episode: Finished after 72 steps : 10試行の平均step数 = 73.9
# 231 Episode: Finished after 71 steps : 10試行の平均step数 = 75.6
# 232 Episode: Finished after 69 steps : 10試行の平均step数 = 75.4
# 233 Episode: Finished after 77 steps : 10試行の平均step数 = 76.1
# 234 Episode: Finished after 95 steps : 10試行の平均step数 = 75.9
# 235 Episode: Finished after 67 steps : 10試行の平均step数 = 76.6
# 236 Episode: Finished after 85 steps : 10試行の平均step数 = 77.6
# 237 Episode: Finished after 76 steps : 10試行の平均step数 = 78.6
# 238 Episode: Finished after 60 steps : 10試行の平均step数 = 75.8
# 239 Episode: Finished after 188 steps : 10試行の平均step数 = 86.0
# 240 Episode: Finished after 200 steps : 10試行の平均step数 = 98.8
# 241 Episode: Finished after 89 steps : 10試行の平均step数 = 100.6
# 242 Episode: Finished after 72 steps : 10試行の平均step数 = 100.9
# 243 Episode: Finished after 140 steps : 10試行の平均step数 = 107.2
# 244 Episode: Finished after 121 steps : 10試行の平均step数 = 109.8
# 245 Episode: Finished after 145 steps : 10試行の平均step数 = 117.6
# 246 Episode: Finished after 123 steps : 10試行の平均step数 = 121.4
# 247 Episode: Finished after 76 steps : 10試行の平均step数 = 121.4
# 248 Episode: Finished after 65 steps : 10試行の平均step数 = 121.9
# 249 Episode: Finished after 99 steps : 10試行の平均step数 = 113.0
# 250 Episode: Finished after 121 steps : 10試行の平均step数 = 105.1
# 251 Episode: Finished after 105 steps : 10試行の平均step数 = 106.7
# 252 Episode: Finished after 78 steps : 10試行の平均step数 = 107.3
# 253 Episode: Finished after 120 steps : 10試行の平均step数 = 105.3
# 254 Episode: Finished after 97 steps : 10試行の平均step数 = 102.9
# 255 Episode: Finished after 98 steps : 10試行の平均step数 = 98.2
# 256 Episode: Finished after 85 steps : 10試行の平均step数 = 94.4
# 257 Episode: Finished after 86 steps : 10試行の平均step数 = 95.4
# 258 Episode: Finished after 86 steps : 10試行の平均step数 = 97.5
# 259 Episode: Finished after 90 steps : 10試行の平均step数 = 96.6
# 260 Episode: Finished after 132 steps : 10試行の平均step数 = 97.7
# 261 Episode: Finished after 84 steps : 10試行の平均step数 = 95.6
# 262 Episode: Finished after 112 steps : 10試行の平均step数 = 99.0
# 263 Episode: Finished after 92 steps : 10試行の平均step数 = 96.2
# 264 Episode: Finished after 200 steps : 10試行の平均step数 = 106.5
# 265 Episode: Finished after 133 steps : 10試行の平均step数 = 110.0
# 266 Episode: Finished after 107 steps : 10試行の平均step数 = 112.2
# 267 Episode: Finished after 163 steps : 10試行の平均step数 = 119.9
# 268 Episode: Finished after 196 steps : 10試行の平均step数 = 130.9
# 269 Episode: Finished after 109 steps : 10試行の平均step数 = 132.8
# 270 Episode: Finished after 130 steps : 10試行の平均step数 = 132.6
# 271 Episode: Finished after 141 steps : 10試行の平均step数 = 138.3
# 272 Episode: Finished after 200 steps : 10試行の平均step数 = 147.1
# 273 Episode: Finished after 99 steps : 10試行の平均step数 = 147.8
# 274 Episode: Finished after 98 steps : 10試行の平均step数 = 137.6
# 275 Episode: Finished after 200 steps : 10試行の平均step数 = 144.3
# 276 Episode: Finished after 200 steps : 10試行の平均step数 = 153.6
# 277 Episode: Finished after 200 steps : 10試行の平均step数 = 157.3
# 278 Episode: Finished after 127 steps : 10試行の平均step数 = 150.4
# 279 Episode: Finished after 110 steps : 10試行の平均step数 = 150.5
# 280 Episode: Finished after 142 steps : 10試行の平均step数 = 151.7
# 281 Episode: Finished after 176 steps : 10試行の平均step数 = 155.2
# 282 Episode: Finished after 200 steps : 10試行の平均step数 = 155.2
# 283 Episode: Finished after 200 steps : 10試行の平均step数 = 165.3
# 284 Episode: Finished after 151 steps : 10試行の平均step数 = 170.6
# 285 Episode: Finished after 128 steps : 10試行の平均step数 = 163.4
# 286 Episode: Finished after 200 steps : 10試行の平均step数 = 163.4
# 287 Episode: Finished after 200 steps : 10試行の平均step数 = 163.4
# 288 Episode: Finished after 127 steps : 10試行の平均step数 = 163.4
# 289 Episode: Finished after 144 steps : 10試行の平均step数 = 166.8
# 290 Episode: Finished after 200 steps : 10試行の平均step数 = 172.6
# 291 Episode: Finished after 200 steps : 10試行の平均step数 = 175.0
# 292 Episode: Finished after 126 steps : 10試行の平均step数 = 167.6
# 293 Episode: Finished after 168 steps : 10試行の平均step数 = 164.4
# 294 Episode: Finished after 114 steps : 10試行の平均step数 = 160.7
# 295 Episode: Finished after 200 steps : 10試行の平均step数 = 167.9
# 296 Episode: Finished after 200 steps : 10試行の平均step数 = 167.9
# 297 Episode: Finished after 200 steps : 10試行の平均step数 = 167.9
# 298 Episode: Finished after 200 steps : 10試行の平均step数 = 175.2
# 299 Episode: Finished after 152 steps : 10試行の平均step数 = 176.0
# 300 Episode: Finished after 200 steps : 10試行の平均step数 = 176.0
# 301 Episode: Finished after 175 steps : 10試行の平均step数 = 173.5
# 302 Episode: Finished after 200 steps : 10試行の平均step数 = 180.9
# 303 Episode: Finished after 200 steps : 10試行の平均step数 = 184.1
# 304 Episode: Finished after 200 steps : 10試行の平均step数 = 192.7
# 305 Episode: Finished after 200 steps : 10試行の平均step数 = 192.7
# 306 Episode: Finished after 200 steps : 10試行の平均step数 = 192.7
# 307 Episode: Finished after 195 steps : 10試行の平均step数 = 192.2
# 308 Episode: Finished after 200 steps : 10試行の平均step数 = 192.2
# 309 Episode: Finished after 200 steps : 10試行の平均step数 = 197.0
# 310 Episode: Finished after 200 steps : 10試行の平均step数 = 197.0
# 311 Episode: Finished after 200 steps : 10試行の平均step数 = 199.5
# 312 Episode: Finished after 191 steps : 10試行の平均step数 = 198.6
# 313 Episode: Finished after 200 steps : 10試行の平均step数 = 198.6
# 314 Episode: Finished after 168 steps : 10試行の平均step数 = 195.4
# 315 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 316 Episode: Finished after 200 steps : 10試行の平均step数 = 195.4
# 317 Episode: Finished after 193 steps : 10試行の平均step数 = 195.2
# 318 Episode: Finished after 200 steps : 10試行の平均step数 = 195.2
# 319 Episode: Finished after 156 steps : 10試行の平均step数 = 190.8
# 320 Episode: Finished after 200 steps : 10試行の平均step数 = 190.8
# 321 Episode: Finished after 200 steps : 10試行の平均step数 = 190.8
# 322 Episode: Finished after 141 steps : 10試行の平均step数 = 185.8
# 323 Episode: Finished after 200 steps : 10試行の平均step数 = 185.8
# 324 Episode: Finished after 200 steps : 10試行の平均step数 = 189.0
# 325 Episode: Finished after 190 steps : 10試行の平均step数 = 188.0
# 326 Episode: Finished after 149 steps : 10試行の平均step数 = 182.9
# 327 Episode: Finished after 200 steps : 10試行の平均step数 = 183.6
# 328 Episode: Finished after 200 steps : 10試行の平均step数 = 183.6
# 329 Episode: Finished after 200 steps : 10試行の平均step数 = 188.0
# 330 Episode: Finished after 200 steps : 10試行の平均step数 = 188.0
# 331 Episode: Finished after 200 steps : 10試行の平均step数 = 188.0
# 332 Episode: Finished after 200 steps : 10試行の平均step数 = 193.9
# 333 Episode: Finished after 200 steps : 10試行の平均step数 = 193.9
# 334 Episode: Finished after 200 steps : 10試行の平均step数 = 193.9
# 335 Episode: Finished after 200 steps : 10試行の平均step数 = 194.9
# 336 Episode: Finished after 200 steps : 10試行の平均step数 = 200.0
# 10回連続成功
# 337 Episode: Finished after 185 steps : 10試行の平均step数 = 198.5
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgDNDIQWXIXKSKTHJO">
#     <br>
#     <input id="_anim_sliderDNDIQWXIXKSKTHJO" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animDNDIQWXIXKSKTHJO.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animDNDIQWXIXKSKTHJO.slower()">&#8211;</button>
#     <button onclick="animDNDIQWXIXKSKTHJO.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animDNDIQWXIXKSKTHJO.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectDNDIQWXIXKSKTHJO" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgDNDIQWXIXKSKTHJO";
#     var slider_id = "_anim_sliderDNDIQWXIXKSKTHJO";
#     var loop_select_id = "_anim_loop_selectDNDIQWXIXKSKTHJO";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
